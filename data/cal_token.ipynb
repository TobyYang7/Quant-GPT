# %%
import pandas as pd
from tqdm import tqdm
from transformers import AutoTokenizer

model_name = "/home/zhangmin/.cache/modelscope/hub/qwen/Qwen-7B-Chat"
tokenizer = AutoTokenizer.from_pretrained(model_name,  trust_remote_code=True)


def calculate_token_length(text):
    # model_name = "/home/zhangmin/.cache/modelscope/hub/qwen/Qwen-7B-Chat"
    # tokenizer = AutoTokenizer.from_pretrained(model_name,  trust_remote_code=True)
    global tokenizer
    tokens = tokenizer.encode(text, truncation=True)
    return len(tokens)


stock_list = ["600031.SH", "600036.SH", "600050.SH", "600104.SH", "600346.SH", "600570.SH", "600887.SH", "601390.SH", "603160.SH", "601668.SH"]

for stock in tqdm(stock_list):
    df = pd.read_parquet(f'./announcement/{stock}.parquet')
    df['token_count'] = df['content'].apply(calculate_token_length)
    df.to_parquet(f'./token/{stock}_token.parquet')
# Out:
# 100%|██████████| 10/10 [00:33<00:00,  3.38s/it]

# %%
df = pd.read_parquet(f'./token/600031.SH_token.parquet')

# %%
df
# Out:
#      ann_date    ts_code  name                                   title  \
# 0    20240412  600031.SH  三一重工            三一重工股份有限公司2024年第二次临时股东大会会议资料
# 1    20240412  600031.SH  三一重工  湖南启元律师事务所关于三一重工股份有限公司2024年员工持股计划的法律意见书
# 2    20240404  600031.SH  三一重工         三一重工股份有限公司关于召开2024年第二次临时股东大会的通知
# 3    20240404  600031.SH  三一重工              三一重工股份有限公司第八届监事会第十七次会议决议公告
# 4    20240404  600031.SH  三一重工                  三一重工股份有限公司可持续发展委员会工作细则
# ..        ...        ...   ...                                     ...
# 565  20181224  600031.SH  三一重工                        三一重工：关于收到政府补助的公告
# 566  20181224  600031.SH  三一重工              三一重工：关于使用自有闲置资金购买理财产品的进展公告
# 567  20181207  600031.SH  三一重工                 三一重工：2018年第二次临时股东大会会议资料
# 568  20181024  600031.SH  三一重工                    三一重工：2018年前三季度业绩预增公告
# 569  20181010  600031.SH  三一重工            三一重工：可转债转股及股票期权自主行权结果暨股份变动公告
#
#                                                    url             rec_time  \
# ...

# %%
import pandas as pd

df = pd.read_parquet('/home/zhangmin/toby/Quant-GPT/data/announcement/processed_LLM_data_test_1_10_30_16k_summary.parquet')

# %%
df
# Out:
#          symbol                time  \
# 489   600031.SH 2023-04-14 09:00:00
# 490   600031.SH 2023-04-25 09:00:00
# 491   600031.SH 2023-04-25 09:00:00
# 492   600031.SH 2023-04-26 09:00:00
# 493   600031.SH 2023-04-26 09:00:00
# ...         ...                 ...
# 1648  600050.SH 2024-03-20 09:00:00
# 1649  600050.SH 2024-04-02 09:00:00
# 1650  600050.SH 2024-04-11 09:00:00
# 1651  600050.SH 2024-04-11 09:00:00
# 1652  600050.SH 2024-04-11 09:00:00
#
#                                                 content     log_r
# 489   现在是2023-04-14 09:00:00+08:00\n时间：2023-03-31 20... -0.015666
# 490   现在是2023-04-25 09:00:00+08:00\n时间：2023-03-31 20... -0.031186
# 491   现在是2023-04-25 09:00:00+08:00\n时间：2023-03-31 20... -0.031186
# 492   现在是2023-04-26 09:00:00+08:00\n时间：2023-03-31 20...  0.005575
# 493   现在是2023-04-26 09:00:00+08:00\n时间：2023-03-31 20...  0.005575
# ...                                                 ...       ...
# ...
